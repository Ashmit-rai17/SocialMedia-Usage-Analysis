# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mental_health.csv")

# %%
df.head()
# Out:
#   User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0    U001   44    Male                     3.1                  7.0
# 1    U002   30   Other                     5.1                  7.0
# 2    U003   23   Other                     7.4                  6.0
# 3    U004   36  Female                     5.7                  7.0
# 4    U005   34  Female                     7.0                  4.0
#
#    Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# 0                 6.0                        2.0                       5.0
# 1                 8.0                        5.0                       3.0
# 2                 7.0                        1.0                       3.0
# 3                 8.0                        1.0                       1.0
# 4                 7.0                        5.0                       1.0
#
#   Social_Media_Platform  Happiness_Index(1-10)
# 0              Facebook                   10.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    500 non-null    object
#  1   Age                        500 non-null    int64
#  2   Gender                     500 non-null    object
#  3   Daily_Screen_Time(hrs)     500 non-null    float64
#  4   Sleep_Quality(1-10)        500 non-null    float64
#  5   Stress_Level(1-10)         500 non-null    float64
#  6   Days_Without_Social_Media  500 non-null    float64
#  7   Exercise_Frequency(week)   500 non-null    float64
#  8   Social_Media_Platform      500 non-null    object
#  9   Happiness_Index(1-10)      500 non-null    float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#               Age  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# count  500.000000              500.000000           500.000000
# mean    32.988000                5.530000             6.304000
# std      9.960637                1.734877             1.529792
# min     16.000000                1.000000             2.000000
# 25%     24.000000                4.300000             5.000000
# 50%     34.000000                5.600000             6.000000
# 75%     41.000000                6.700000             7.000000
# max     49.000000               10.800000            10.000000
#
#        Stress_Level(1-10)  Days_Without_Social_Media  \
# count          500.000000                 500.000000
# mean             6.618000                   3.134000
# std              1.542996                   1.858751
# min              2.000000                   0.000000
# 25%              6.000000                   2.000000
# 50%              7.000000                   3.000000
# ...

# %%
df.isna().sum()
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Daily_Screen_Time(hrs)       0
# Sleep_Quality(1-10)          0
# Stress_Level(1-10)           0
# Days_Without_Social_Media    0
# Exercise_Frequency(week)     0
# Social_Media_Platform        0
# Happiness_Index(1-10)        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.columns:    
    plt.Figure(figsize=(3 , 4))
    sns.boxplot(df[col])
    plt.show()

# %%
df.describe()
# Out:
#               Age  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# count  500.000000              500.000000           500.000000
# mean    32.988000                5.530000             6.304000
# std      9.960637                1.734877             1.529792
# min     16.000000                1.000000             2.000000
# 25%     24.000000                4.300000             5.000000
# 50%     34.000000                5.600000             6.000000
# 75%     41.000000                6.700000             7.000000
# max     49.000000               10.800000            10.000000
#
#        Stress_Level(1-10)  Days_Without_Social_Media  \
# count          500.000000                 500.000000
# mean             6.618000                   3.134000
# std              1.542996                   1.858751
# min              2.000000                   0.000000
# 25%              6.000000                   2.000000
# 50%              7.000000                   3.000000
# ...

# %%
df.describe().columns
# Out:
# Index(['Age', 'Daily_Screen_Time(hrs)', 'Sleep_Quality(1-10)',
#        'Stress_Level(1-10)', 'Days_Without_Social_Media',
#        'Exercise_Frequency(week)', 'Happiness_Index(1-10)'],
#       dtype='object')

# %% [markdown]
# NOW , WE CHECK HOW MUCH TIME IS BEING SPENT ON EACH SOCIAL MEDIA PLATFORM.

# %%
sns.barplot(x = df["Daily_Screen_Time(hrs)"] , y = df["Social_Media_Platform"])
# Out:
# <Axes: xlabel='Daily_Screen_Time(hrs)', ylabel='Social_Media_Platform'>

# %% [markdown]
# Instagram and Facebook are the most used platforms.

# %%
for col in ['Age', 'Daily_Screen_Time(hrs)', 'Sleep_Quality(1-10)',
       'Stress_Level(1-10)', 'Days_Without_Social_Media',
       'Exercise_Frequency(week)', 'Happiness_Index(1-10)']:
    sns.histplot(df[col])
    plt.show()

# %%
sns.barplot(df["Gender"])
# Out:
# <Axes: ylabel='Gender'>

# %%
sns.barplot(df["Social_Media_Platform"])
# Out:
# <Axes: ylabel='Social_Media_Platform'>

# %% [markdown]
# Here , we performed univariate analysis and these are the following observations :
# 1. Most continuous variables have no missing values and are non-skewed except some variables like stress level or exercise frequency where models can develop a bias.
# 2. Categorical values have an almost equal distribution of data.
# 3. Values like age address class imbalance , wherein , data of adults and middle age people is more compared to other age groups.

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
df.columns
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Daily_Screen_Time(hrs)',
#        'Sleep_Quality(1-10)', 'Stress_Level(1-10)',
#        'Days_Without_Social_Media', 'Exercise_Frequency(week)',
#        'Social_Media_Platform', 'Happiness_Index(1-10)'],
#       dtype='object')

# %%
def GroupAge(x):
    if x < 18:
        return "Teenager"
    elif 18 <= x < 30:
        return "Adult"
    elif 30 <= x < 45:
        return "Middle-Aged"
    else:
        return "Old"
df["GroupAge"] = df["Age"].apply(GroupAge)

# %%
sns.boxplot(x = df["Days_Without_Social_Media"] , y=df["GroupAge"])
# Out:
# <Axes: xlabel='Days_Without_Social_Media', ylabel='GroupAge'>

# %%
sns.boxplot(x = df["Days_Without_Social_Media"] , y = df["GroupAge"])
# Out:
# <Axes: xlabel='Days_Without_Social_Media', ylabel='GroupAge'>

# %% [markdown]
# Observation:
# An interesting finding from the distribution is that teenagers exhibit a higher median number of days without social media compared to other age groups. This suggests that, despite being the most active demographic on social platforms, teenagers in this dataset may also show a greater ability or willingness to take breaks from social media. In contrast, adults and middle-aged users tend to have shorter breaks, possibly reflecting stronger integration of social media into their daily routines or professional lives.
#
# However , we cannot conclude anything due to teens being a small part of the dataset

# %%
sns.boxplot(y= df["Sleep_Quality(1-10)"] , x = df["Stress_Level(1-10)"])
# Out:
# <Axes: xlabel='Stress_Level(1-10)', ylabel='Sleep_Quality(1-10)'>

# %% [markdown]
# Box plots are very useful in plotting discrete random variables

# %%
sns.boxplot(y = df["Daily_Screen_Time(hrs)"] , x = df["Stress_Level(1-10)"])
# Out:
# <Axes: xlabel='Stress_Level(1-10)', ylabel='Daily_Screen_Time(hrs)'>

# %%
hmap_df = df.drop(["User_ID" , "Gender" , "Social_Media_Platform" , "GroupAge"] , axis=1)
sns.heatmap(data=hmap_df.corr() ,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Bivariate / Correlation Analysis
#
# The correlation matrix highlights strong interrelationships among the variables Stress Level, Daily Screen Time, Sleep Quality, and Happiness Index.
# A clear behavioral pattern emerges:
#
# As Stress Level increases, Daily Screen Time tends to rise, while both Sleep Quality and Happiness Index decline.
#
# Sleep Quality shows a strong negative correlation with Stress Level and Daily Screen Time, suggesting that higher stress and prolonged screen exposure are associated with poorer sleep.
#
# Happiness Index is also negatively correlated with both Stress Level and Screen Time, implying that individuals with higher stress and screen usage generally report lower happiness.
#
# Overall, these trends suggest that stress, digital habits, and sleep quality are closely intertwined, and together they significantly influence one’s overall sense of happiness and well-being.

# %% [markdown]
# “Males and females have comparable median sleep quality (~6), though males show greater variability. Individuals identifying as ‘Other’ report slightly higher and more consistent sleep quality.”

# %% [markdown]
# Its clear , we have four very important features here , those are:
# 1. Daily Screen Time
# 2. Stress Level
# 3. Exercise Frequency
# 4. Happiness Index
# These four features co-relate to each other highly , and help in telling a story

# %%
df[df["Age"].notnull()]
# Out:
#     User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0      U001   44    Male                     3.1                  7.0
# 1      U002   30   Other                     5.1                  7.0
# 2      U003   23   Other                     7.4                  6.0
# 3      U004   36  Female                     5.7                  7.0
# 4      U005   34  Female                     7.0                  4.0
# ..      ...  ...     ...                     ...                  ...
# 495    U496   23    Male                     6.9                  5.0
# 496    U497   43  Female                     5.6                  7.0
# 497    U498   41    Male                     7.7                  5.0
# 498    U499   23    Male                     4.2                  9.0
# 499    U500   43  Female                     5.9                  5.0
#
#      Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# ...

# %%
df["GroupAge"].value_counts()
# Out:
# GroupAge
# Middle-Aged    232
# Adult          160
# Old             74
# Teenager        34
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="GroupAge", hue="Social_Media_Platform")
# Out:
# <Axes: xlabel='GroupAge', ylabel='count'>

# %% [markdown]
# This countplot is not statistically accurate due to the fact that there are more middle aged people in the sample , for making this graph right , we need to normalize all the values according to their propoertion.

# %%
sns.boxplot(x = df["Daily_Screen_Time(hrs)"] , y = df["GroupAge"])
# Out:
# <Axes: xlabel='Daily_Screen_Time(hrs)', ylabel='GroupAge'>

# %% [markdown]
# Looking at this , we can see the spread for each age group according to their daily screen time , the medians among all the age groups can be considered almost the same , however , we can takeout some general insights from this:
# 1. Old aged people have more outliers among them
# 2. Adults have more varied inter-quartile range suggesting the variance in their daily screen time

# %%
sns.boxplot(x = df["Stress_Level(1-10)"] , y = df["GroupAge"])
# Out:
# <Axes: xlabel='Stress_Level(1-10)', ylabel='GroupAge'>

# %% [markdown]
# The median stress level of each age group has been represented in the above graphs:
# 1. Old people have a higher median stress level as well as a higher spread , but this could also be due to class imbalance
# 2. Middle aged and adults almost have the same median stress , but adults do have a larger spread
# 3. Teenagers have an overall lower stress level compared to the other age groups , but the spread is almost same as adults

# %%
sns.boxplot(x = df["Exercise_Frequency(week)"] , y = df["GroupAge"])
# Out:
# <Axes: xlabel='Exercise_Frequency(week)', ylabel='GroupAge'>

# %%
sns.boxplot(x = df["Sleep_Quality(1-10)"] , y = df["GroupAge"])
# Out:
# <Axes: xlabel='Sleep_Quality(1-10)', ylabel='GroupAge'>

# %% [markdown]
# The boxplot reveals that teenagers report higher sleep quality scores compared to all other age groups, with their median sleep rating being noticeably above that of adults, middle-aged, and older individuals. This suggests that teenagers in the dataset generally experience better and more consistent sleep, possibly due to fewer work-related pressures or lifestyle factors that tend to disrupt sleep patterns in older age groups.

# %%
sns.boxplot(x=df["Days_Without_Social_Media"] , y=df["GroupAge"])
# Out:
# <Axes: xlabel='Days_Without_Social_Media', ylabel='GroupAge'>

# %%
sns.boxplot(x=df["Happiness_Index(1-10)"] , y=df["GroupAge"])
# Out:
# <Axes: xlabel='Happiness_Index(1-10)', ylabel='GroupAge'>

# %%
pd.crosstab(df['GroupAge'], df['Social_Media_Platform'], normalize='index').plot(kind='bar')
# Out:
# <Axes: xlabel='GroupAge'>

# %% [markdown]
# This is a more group-based percentage distribution according to each age group as we implemented the crosstab function which is essentially groupby funtion mixed with unstack and normalization funtion in .apply()
# These are the following observations , we observed in the dataset:
#
#
# Adults and Middle-Aged groups appear to have relatively balanced platform preferences (diversified social media usage). Adults having a bias towards platforms like X.
#
# Teenagers might show stronger relative proportions for TikTok and Instagram, consistent with real-world trends.
#
# Older groups likely lean toward Facebook and LinkedIn, showing more conservative platform choices

# %%
df.groupby('GroupAge')[['Exercise_Frequency(week)','Stress_Level(1-10)']].corr()
# Out:
#                                       Exercise_Frequency(week)  \
# GroupAge
# Adult       Exercise_Frequency(week)                  1.000000
#             Stress_Level(1-10)                       -0.001121
# Middle-Aged Exercise_Frequency(week)                  1.000000
#             Stress_Level(1-10)                       -0.034282
# Old         Exercise_Frequency(week)                  1.000000
#             Stress_Level(1-10)                        0.104810
# Teenager    Exercise_Frequency(week)                  1.000000
#             Stress_Level(1-10)                       -0.278571
#
#                                       Stress_Level(1-10)
# GroupAge
# Adult       Exercise_Frequency(week)           -0.001121
#             Stress_Level(1-10)                  1.000000
# Middle-Aged Exercise_Frequency(week)           -0.034282
#             Stress_Level(1-10)                  1.000000
# Old         Exercise_Frequency(week)            0.104810
# ...

# %% [markdown]
# Summary of Age Group Analysis
#
# 1. Across different age demographics, clear behavioral distinctions emerge. Teenagers show the lowest overall stress levels and a moderate screen-time pattern, with a negative correlation between exercise and stress , indicating that physical activity strongly contributes to emotional balance in this group.
# However , we cannot conclude anything yet owing to data imbalance
# 2. Adults display moderate stress and exercise levels, reflecting a relatively balanced but somewhat inconsistent lifestyle.
# 3. Middle-aged individuals experience comparable median stress to adults but exhibit a wider spread, suggesting greater lifestyle variability — possibly due to work or family responsibilities. Interestingly, older participants demonstrate the highest median exercise frequency yet also the highest stress levels and variability.
# This counterintuitive finding may suggest that, for older individuals, stress could stem less from inactivity and more from age-related health or social factors, highlighting that physical activity alone doesn’t necessarily equate to lower stress in this demographic.

# %%
df.groupby("GroupAge")[["Daily_Screen_Time(hrs)", "Exercise_Frequency(week)", "Stress_Level(1-10)", "Sleep_Quality(1-10)", "Happiness_Index(1-10)"]].median()
# Out:
#              Daily_Screen_Time(hrs)  Exercise_Frequency(week)  \
# GroupAge
# Adult                          5.35                       2.0
# Middle-Aged                    5.60                       2.0
# Old                            5.90                       3.0
# Teenager                       5.50                       2.0
#
#              Stress_Level(1-10)  Sleep_Quality(1-10)  Happiness_Index(1-10)
# GroupAge
# Adult                       7.0                  6.0                    8.0
# Middle-Aged                 7.0                  6.0                    9.0
# Old                         7.0                  6.0                    8.0
# Teenager                    6.0                  7.0                    9.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    500 non-null    object
#  1   Age                        500 non-null    int64
#  2   Gender                     500 non-null    object
#  3   Daily_Screen_Time(hrs)     500 non-null    float64
#  4   Sleep_Quality(1-10)        500 non-null    float64
#  5   Stress_Level(1-10)         500 non-null    float64
#  6   Days_Without_Social_Media  500 non-null    float64
#  7   Exercise_Frequency(week)   500 non-null    float64
#  8   Social_Media_Platform      500 non-null    object
#  9   Happiness_Index(1-10)      500 non-null    float64
#  10  GroupAge                   500 non-null    object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 43.1+ KB

# %% [markdown]
# ANALYSING THE SPREAD OF NUMERIC VALUES AMONG ALL AGE GROUPS BY MEANS OF A HISTOGRAM

# %%
num_cols = ["Daily_Screen_Time(hrs)" , "Sleep_Quality(1-10)" , "Stress_Level(1-10)" , "Days_Without_Social_Media" , "Exercise_Frequency(week)" , "Happiness_Index(1-10)"]

# %%
for col in num_cols:
    plt.Figure(figsize=(5 , 6))
    sns.histplot(data=df , x=col , hue="GroupAge" , multiple="stack")
    plt.show()

# %% [markdown]
# Demographic Insights
# Middle-Aged Group (Dominant Demographic):
#
# Highest screen time usage
# Strongest social media attachment
# Highest stress levels
# Largest sedentary population
# Most represented across all metrics
#
# Adults:
#
# Moderate patterns across all variables
# More balanced lifestyle indicators
# Consistent but varied behaviors
#
# Teenagers & Elderly:
#
# Minimal representation in the dataset
# Elderly show lower digital engagement and stress
# Both groups underrepresented, limiting conclusive insights

# %% [markdown]
# Critical Correlations & Concerns
#
# Digital-Health Connection: High screen time and constant social media use may correlate with elevated stress and compromised sleep quality, particularly in middle-aged individuals
# Exercise Deficit: The inverse relationship between exercise frequency and participation, combined with high sedentary rates, suggests systemic barriers to physical activity
# Middle-Aged Crisis: This demographic shows the most concerning patterns - highest screen time, strongest social media dependency, highest stress, and poorest exercise habits
# Lifestyle Sustainability: The concentration around moderate frequencies (2-day exercise, 5-7 hour screen time) suggests people gravitate toward "manageable" but not necessarily optimal habits

# %% [markdown]
# MULTIVARIATE ANALYSIS ACCORDING TO THE AGE GROUP OF VARIOUS PERSONS

# %%
sns.heatmap(df.groupby("GroupAge").corr(numeric_only=True))
# Out:
# <Axes: ylabel='GroupAge-None'>

# %% [markdown]
# CHECKING LINEAR AND NON LINEAR PATTERNS

# %%
num_cols = ["Daily_Screen_Time(hrs)" , "Sleep_Quality(1-10)" , "Stress_Level(1-10)" , "Days_Without_Social_Media" , "Exercise_Frequency(week)" , "Happiness_Index(1-10)"]

# %%
sns.boxplot(data=df , y="Happiness_Index(1-10)" , x="Days_Without_Social_Media" )
# Out:
# <Axes: xlabel='Days_Without_Social_Media', ylabel='Happiness_Index(1-10)'>

# %%
sns.boxplot(data=df , y="Happiness_Index(1-10)" , x="Days_Without_Social_Media" , hue="GroupAge")
# Out:
# <Axes: xlabel='Days_Without_Social_Media', ylabel='Happiness_Index(1-10)'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='GroupAge', hue='GroupAge', palette='Set2', legend=False)
plt.title('Sample Size by Age Group')
plt.ylabel('Number of Respondents')
plt.show()

# %% [markdown]
# ### Handling Class Imbalance: Ethical & Statistical Approach
#
# #### 1. **Observed Imbalance**
# | Group       | n   | %     |
# |-------------|-----|-------|
# | Middle-Aged | 232 | 46%   |
# | Adult       | 160 | 32%   |
# | Old         | 74  | 15%   |
# | Teenager    | 34  | 7%    |
#
#
# > **All Teenager and Old people trend is suggestive but not conclusive**
# #### 4. **Recommendation**
# > **Future study**: Collect **stratified sample** with **≥100 per age group**.

# %% [markdown]
# # Mental Health EDA: Age-Group Insights & Limitations
#
# **Objective**: Explore how age groups influence mental health metrics (e.g., happiness, stress) tied to social media and lifestyle in a 500-row dataset.
#
# **Key Findings**:
# - Overall: No strong correlations (e.g., social media breaks vs. happiness: Spearman ρ=0.079, p=0.079).
# - Age-Specific: Initial trends (e.g., teens prefer TikTok; exercise reduces teen stress) but qualified by severe imbalance (teens=7% of data).
# - Limitations: Small subgroups (e.g., n<5 in some teen cells) make teen/old insights suggestive, not conclusive.
# - Recommendations: Stratified sampling for future data; weighted analysis for current.
#
# **Process**: Started with descriptives/correlations, then validated with quality checks. Full code & rationale below.
